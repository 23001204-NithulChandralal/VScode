# %%
# Start Code Here
from turtle import *
turtle = Turtle()
turtle.penup()
turtle.backward(45)
turtle.left(90)
turtle.forward(45)
turtle.right(90)
turtle.pendown()
turtle.begin_fill()
turtle.color("blue")
turtle.forward(90)
turtle.right(90)
turtle.forward(90)
turtle.right(135)
turtle.forward(125)
turtle.right(135)
turtle.end_fill()
turtle.penup()
turtle.forward(90)
turtle.right(90)
turtle.forward(90)
turtle.pendown()
turtle.begin_fill()
turtle.color("pink")
turtle.forward(90)
turtle.right(90)
turtle.forward(90)
turtle.right(135)
turtle.forward(125)
turtle.right(135)
turtle.backward(3)
turtle.end_fill()
turtle.begin_fill()
turtle.color("green")
turtle.right(45)
turtle.forward(45)
turtle.right(90)
turtle.forward(45)
turtle.right(90)
turtle.forward(45)
turtle.end_fill()
turtle.penup()
turtle.left(180)
turtle.forward(45)
turtle.pendown()
turtle.begin_fill()
turtle.color("aqua")
turtle.forward(55)
turtle.right(135)
turtle.forward(40)
turtle.right(90)
turtle.forward(40)
turtle.end_fill()
turtle.penup()
turtle.backward(40)
turtle.pendown()
turtle.begin_fill()
turtle.color("red")
turtle.right(90)
turtle.forward(40)
turtle.right(90)
turtle.forward(40)
turtle.right(135)
turtle.forward(58)
turtle.end_fill()
turtle.penup()
turtle.right(45)
turtle.forward(40)
turtle.left(90)
turtle.left(45)
turtle.pendown()
turtle.begin_fill()
turtle.color("orange")
turtle.forward(60)
turtle.left(45)
turtle.forward(40)
turtle.left(45)
turtle.left(90)
turtle.forward(60)
turtle.end_fill()
turtle.penup()
turtle.left(45)
turtle.forward(105)
turtle.pendown()
turtle.begin_fill()
turtle.color("purple")
turtle.right(90)
turtle.forward(30)
turtle.left(135)
turtle.forward(40)
turtle.left(90)
turtle.forward(43)
turtle.left(135)
turtle.forward(60)
turtle.end_fill()
done()
