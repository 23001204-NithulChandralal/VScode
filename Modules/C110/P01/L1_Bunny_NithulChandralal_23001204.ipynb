# %%
'''
This is a program to draw a bunny 
'''
# Start Code Here
from turtle import *
turtle = Turtle()

# select the colour orange
turtle.begin_fill()
turtle.color("orange")
turtle.left(135)
turtle.forward(50)
turtle.left(45)
turtle.forward(60)
turtle.left(135)
turtle.forward(50)
turtle.left(45)
turtle.forward(60)
turtle.end_fill() # stop colouring
turtle.begin_fill()
turtle.color("green")
turtle.forward(25)
turtle.right(90)
turtle.forward(60)
turtle.right(90)
turtle.forward(50)
turtle.right(90)
turtle.forward(60)
turtle.right(25)
turtle.end_fill()
turtle.begin_fill()
turtle.color("blue")
turtle.right(155)
turtle.forward(30)
turtle.right(45)
turtle.forward(110)
turtle.left(135)
turtle.forward(78)
turtle.left(90)
turtle.end_fill()
turtle.forward(80)
turtle.backward(55)
turtle.begin_fill()
turtle.color("cyan")
turtle.right(135)
turtle.forward(40)
turtle.right(90)
turtle.forward(40)
turtle.right(135)
turtle.forward(60)
turtle.end_fill()
turtle.backward(30)
turtle.begin_fill()
turtle.color("pink")
turtle.right(225)
turtle.forward(110)
turtle.right(135)
turtle.forward(80)
turtle.right(90)
turtle.end_fill()
turtle.right(90)
turtle.forward(80)
turtle.begin_fill()
turtle.color("purple")
turtle.left(90)
turtle.forward(50)
turtle.left(90)
turtle.forward(48)
turtle.end_fill()
turtle.begin_fill()
turtle.color("red")
turtle.right(145)
turtle.forward(60)
turtle.right(125)
turtle.forward(35)
turtle.end_fill()
turtle.backward(35)
turtle.right(180)
done()
