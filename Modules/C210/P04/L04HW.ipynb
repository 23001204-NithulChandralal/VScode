# %%
#Q1
import pandas as pd
df = pd.DataFrame({
    "A" : [12,4,5,44,1],
    "B" : [5,2,54,3,2],
    "C" : [20,16,7,3,8],
    "D" : [14,3,17,2,6]})

df
# Out:
#     A   B   C   D
# 0  12   5  20  14
# 1   4   2  16   3
# 2   5  54   7  17
# 3  44   3   3   2
# 4   1   2   8   6

# %%
#Q2
df_m = pd.melt(df, id_vars=['A'], 
                value_vars=['B'] )
df_m
# Out:
#     A variable  value
# 0  12        B      5
# 1   4        B      2
# 2   5        B     54
# 3  44        B      3
# 4   1        B      2

# %%
#Q3
df_m = pd.melt(df,id_vars=['A'],
               value_vars = ['B','C'])

df_m
# Out:
#     A variable  value
# 0  12        B      5
# 1   4        B      2
# 2   5        B     54
# 3  44        B      3
# 4   1        B      2
# 5  12        C     20
# 6   4        C     16
# 7   5        C      7
# 8  44        C      3
# 9   1        C      8

# %%
#Q4
df = pd.read_excel("alphabet_stock_data.xlsx")


df.plot(x='Date', y='Close',xlabel="Date",ylabel="$ Price", color='green', label='Close',title = "Stock Pricing")
# Out:
# <Axes: title={'center': 'Stock Pricing'}, xlabel='Date', ylabel='$ Price'>

# %%
#Q5
df['Date'] = pd.to_datetime(df['Date'])

start_date = '2020-04-01'
end_date = '2020-07-01'
filtered_df = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]


filtered_df.plot(x='Date', y='Close', color='green', label='Close')
# Out:
# <Axes: xlabel='Date'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       127 non-null    datetime64[ns]
#  1   Open       127 non-null    float64
#  2   High       127 non-null    float64
#  3   Low        127 non-null    float64
#  4   Close      127 non-null    float64
#  5   Adj Close  127 non-null    float64
#  6   Volume     127 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 7.1 KB

# %%
#Q5
df['Date'] = pd.to_datetime(df['Date'])

start_date = '2020-04-01'
end_date = '2020-04-30'
filtered_df = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

filtered_df.plot(kind="bar",x='Date', y='Volume', color='blue', label='Volume')
# Out:
# <Axes: xlabel='Date'>
